# %% [markdown]
# # Proyek Tugas Akhir Microcredential Associate Data Scientist

# %% [markdown]
# * Nama Peserta:
#   - Arwendy Melyndra
#   - Julius Ivander Massie
#   - Samuel Goesniady
#   - Maria Auleria
# * Universitas Host: UGM
# * Kelas: 03
# * Kelompok: 1
# * Tema Project Kelompok: Deteksi Penggunaan Masker
#
# #### Deskripsi Masalah
# Hingga saat ini, pandemi covid-19 terus melanda. Terdapat banyak upaya yang telah dilakukan oleh pemerintah, salah satunya adalah Pemberlakuan Pembatasan Kegiatan Masyarakat atau dikenal dengan PPKM. Berdasarkan data yang dilansir covid19.go.id, program tersebut sukses menekan kasus covid-19 di Indonesia. Akan tetapi, masyarakat Indonesia tidak boleh lengah dan terus mematuhi protokol kesehatan, salah satunya adalah dengan mengenakan masker. Namun nyatanya, banyak masyarakat Indonesia tidak mengenakan masker ketika berada diluar rumah sehingga dikemukakan sistem deteksi pemakaian masker. Tantangan utama dalam sistem deteksi pemakaian masker ini adalah bagaimana mengenali sebuah gambar seseorang memakai masker dan tidak memakai masker yang dapat mengetahui pemakaian masker secara benar atau tidak. Sehingga permasalahan utama yang diselesaikan adalah bagaimana mengimplementasikan metode deteksi area wajah pada gambar.

# %% [markdown]
# **NOTE**: File notebook ini berisi gabungan dari seluruh file project yang dilakukan dan notebook ini hanya menjalankan proses pelatihan model dan evaluasi model. Pada proyek ini kami menggunakan **Anaconda** (Sebagai proses data gathering dan preparation) dan **Google Colab** (Sebagai proses data training)

# %% [markdown]
# ***STRUKTUR PROYEK SEBELUM MELAKUKAN DATA PREPARATION***
# ```
# Project
# |   README.md
# |
# |___addson
# |
# |___dataset
# |   |___images
# |   |___labels
# |
# |___model
# |   |___yolov5
# |
# |___notebook
# |      index.ipynb
# |      1. Scraping image.ipynb
# |      2. Data Preparation.ipynb
# |   |___assets
# ```
#
# Keterangan Project Folder:
# * ***addson*** : Merupakan folder yang berisi aplikasi tambahan yang digunakan sebagai penunjang proyek. Pada proyek ini kami menggunakan labelimg untuk proses data preparation
# * ***dataset***: Merupakan folder yang berisi dataset yang dikumbulkan
#     * images: Berisi gambar yang diperoleh dari proses scraping dataset
#     * labels: Berisi anotasi yang diperoleh dari proses labeling gambar
# * ***model***: Merupakan folder yang berisi model yang akan digunakan dalam proyek. Pada proyek ini kami menggunakan yolov5
# * ***notebook***: Merupakan folder yang berisi source code dari proyek
#     * assets: Berisi asset penunjang notebook

# %% [markdown]
# ## Proses Pengerjaan Proyek

# %% [markdown]
# ### 1. Pengumpulan Dataset
# Untuk mengimplementasi proyek ini, dataset yang diperlukan adalah berbentuk gambar. Untuk memperoleh data tersebut, kami melakukan scraping pada situs google image menggunakan ***BeautifulSoup***.
#
# Dibawah ini merupakan *source code* yang kami gunakan untuk melakukan proses scraping dataset. Proses ini telah dijalankan melalui file jupyter notebook terpisah dengan nama ***1. Scraping image.ipynb***.
#
# Setelah mengumpulkan dataset, langkah selanjutnya adalah melakukan filter secara manual, dimana kami memilah gambar-gambar agar gambar relefan dengan tujuan proyek.
#
# Adapula file dataset yang telah kami kumpulkan melalui link berikut: [LINK DATASET](https://drive.google.com/drive/folders/152ZODHk0ddncvNqf1SHNlpw5w5tuJaIZ?usp=sharing)

# %%
import requests
import os
import re
import json
import shutil
from bs4 import BeautifulSoup as bs

# %%
def get_all_images_url(url, params, headers):
    """
    Fungsi ini digunakan untuk mengambil seluruh source code dari situs google image
    dan melakukan ekstraksi sehingga menghasilkan return value berupa link
    gambar yang di scraping.
    
    Parameter:
    url: string = merupakan link url yang ingin di scrape
    params: dictionary = merupakan parameter dari url
    headers: dictionary = merupakan header dari url 
    """
    urls = []
    
    html = requests.get(url, params=params, headers=headers)
    soup = bs(html.text, "html.parser")
    
    # this steps could be refactored to a more compact
    all_script_tags = soup.select('script')
    
    # https://regex101.com/r/48UZhY/4 [Hasil]
    matched_images_data = ''.join(re.findall(r"AF_initDataCallback\(([^<]+)\);", 
                                             str(all_script_tags)))
    
    # if you try to json.loads() without json.dumps it will throw an error:
    # "Expecting property name enclosed in double quotes"
    matched_images_data_fix = json.dumps(matched_images_data)
    matched_images_data_json = json.loads(matched_images_data_fix)
    
    # https://regex101.com/r/pdZOnW/3 [Hasil]
    matched_google_image_data = re.findall(r'\[\"GRID_STATE0\",null,\[\[1,\[0,\".*?\",(.*),\"All\",', 
                                           matched_images_data_json)
    
    # https://regex101.com/r/NnRg27/1 [Hasil]
    matched_google_images_thumbnails = ', '.join(
        re.findall(r'\[\"(https\:\/\/encrypted-tbn0\.gstatic\.com\/images\?.*?)\",\d+,\d+\]',
                   str(matched_google_image_data))).split(', ')
    
    # removing previously matched thumbnails for easier full resolution image matches.
    removed_matched_google_images_thumbnails = re.sub(
        r'\[\"(https\:\/\/encrypted-tbn0\.gstatic\.com\/images\?.*?)\",\d+,\d+\]', '', 
        str(matched_google_image_data))
    
    # https://regex101.com/r/fXjfb1/4
    # https://stackoverflow.com/a/19821774/15164646
    matched_google_full_resolution_images = re.findall(r"(?:'|,),\[\"(https:|http.*?)\",\d+,\d+\]",
                                                       removed_matched_google_images_thumbnails)
    
    for index, fixed_full_res_image in enumerate(matched_google_full_resolution_images):
        # https://stackoverflow.com/a/4004439/15164646 comment by Frédéric Hamidi
        original_size_img_not_fixed = bytes(fixed_full_res_image, 'ascii').decode('unicode-escape')
        original_size_img = bytes(original_size_img_not_fixed, 'ascii').decode('unicode-escape')
        urls.append(original_size_img)
    return urls

# %%
def download(url, pathname):
    """
    Fungsi ini digunakan untuk mengunduh seluruh gambar
    dari url yang diperoleh dari hasil ekstraksi situs google image.
    Hasil unduhan tersebut kemudian akan disimpan kedalam path yang telah ditentukan
    
    Parameter:
    url: string = link gambar yang ingin diunduh
    pathname: string = path atau jalur folder tempat gambar diunduh
    """
    try:
        response = requests.get(url, stream=True)
        filename = re.sub(r'[^ \nA-Za-z0-9/]+', '', url)
        filepath = os.path.join(pathname, filename.split("/")[-1])
    
        file = open("{}.jpg".format(filepath), "wb")
        response.raw.decode_content = True
        shutil.copyfileobj(response.raw, file)
        print("{} downloaded".format(filename))
    except:
        pass

# %%
def main(url, params, path):
    """
    Fungsi ini berisi persiapan untuk menjalankan
    fungsi get_all_images_url, dan download
    
    Parameter:
    url: string = merupakan link url yang ingin di scrape
    params: dictionary = merupakan parameter dari url
    path: string = path atau jalur folder tempat gambar diunduh
    """
    # Persiapan URL
    headers = {
       "User-Agent":
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
    }
    img_urls = get_all_images_url(url, params, headers)
    for url in img_urls:
        download(url, path)

# %%
params = {
    "q": "orang jogging gbk", #Search nya apa
    "tbm": "isch",
    "ijn": "0"
}
url = "https://www.google.com/search"
path = "..\dataset"

main(url, params, path)

# %% [markdown]
# ### 2. Eksplorasi dan Persiapan Data
# Setelah melakukan proses pengumpulan data, langkah selanjutnya adalah dengan melakukan eksplorasi data dan melakukan persiapan dataset.
#
# Proses persiapan dataset meliputi beberapa proses:

# %% [markdown]
# 1. ***Pelabelan dataset*** <br>
# Sebelum melakukan pelabelan dataset, kami menerapkan model YOLOv5 untuk mengimplementasi proyek. Berdasarkan [sumber](https://www.section.io/engineering-education/introduction-to-yolo-algorithm-for-object-detection/), YOLO merupakan salah satu algoritma yang digunakan untuk menerapkan object detection. Dalam prosesnya, agar model dapat mengindentifikasi dataset, kita perlu melakukan pelabelan terhadap objek dari masing-masing gambar dan disimpan dalam bentuk file txt yang berisi anotasi dari objek serta label dari objek. <br><br>
# Untuk mengimplementasi hal tersebut, kami menggunakan [labelimg](https://github.com/tzutalin/labelImg) untuk melakukan pelabelan data. LabelImg dapat dilakukan instalasi dengan menggunakan perintah pada console berikut:<br><br>
#     ```git clone https://github.com/tzutalin/labelImg.git ```<br><br>
# Instalasi tersebut berbentuk folder proyek dan agar LabelImg dapat berjalan, arahkan console menuju folder proyek tersebut dan jalankan perintah berikut: <br><br>
#     ```conda install pyqt=5```<br>
#     ```conda install -c anaconda lxml``` <br>
#     ```pyrcc5 -o libs/resources.py resources.qrc``` <br><br>
# Setelah menjalankan perintah diatas, langkah selanjutnya adalah melakukan pendefinisian label dataset yakni *mask* dan *no-mask* pada file yang terletak dalam folder proyek LabelImg yakni ```data/predefined_classes.txt```. Sehingga struktur file dari ```predefined_classes.txt``` menjadi seperti berikut:
# ```
# mask
# no-mask
# ```
# Kemudian kembali ke dalam console dengan arah direktori merupakan folder proyek LabelImg, jalankan perintah berikut: <br><br>
#     ```python labelImg.py```<br><br>
# Maka program labelImg akan muncul seperti tampilan [berikut](assets/labelimg.png). Langkah berikutnya adalah menekan tombol open dir untuk membuka lokasi dataset disimpan, kemudian diikuti dengan menekan tombol change save dir sebagai tempat menyimpan lokasi label, langkah ini kemudian diakhiri dengan mengubah format Pascal VOC menjadi YOLO dengan menekan tombol Pascal VOC hingga menemukan YOLO. Maka dari itu gambar dapat dilabel sesuai dengan label yang diberikan dan disimpan dengan menekan tombol save. Setelah melakukan proses save, program akan menyimpan anotasi dari label berbentuk txt dan menyimpan jenis label dengan nama file *classess.txt*. Setelah selesai melakukan pelabelan, langkah terakhir adalah memindahkan file *classess.txt* keluar dari direktori save file label<br><br>
# Pada kasus ini, kami telah menyediakan dataset yang sudah dilabel melalui link berikut: [LINK DATASET](https://drive.google.com/drive/folders/1HT0zIiiu9arMlLFgpCXqi7_7ZiYxMF3a?usp=sharing)

# %% [markdown]
# 2. ***Eksplorasi dan Persiapan dataset*** <br>
# Setelah melakukan pelabelan dataset, langkah selanjutnya adalah melakukan eksplorasi dataset yang meliputi menghitung jumlah label, jumlah gambar, serta menvisualisasikan gambar beserta label yang telah dilabelkan. Persiapan dataset dilakukan dengan pemisahan dataset, serta pembuatan YAML sebagai penunjang model. Proses ini telah dijalankan melalui file jupyter notebook terpisah dengan nama ***2. Data Preparation.ipynb***.<br><br>
# Setelah melakukan proses data preparation, langkah selanjutnya adalah dengan membuat file YAML yang kemudian disimpan ke dalam folder ```workspace\models\v1``` dan  dengan nama ```custom_dataset.yaml``` yang berisi data berikut:<br>
# ```
# path: ../../dataset/
# train: images/train
# val: images/test
# nc: 2
# names: [ 'mask', 'no-mask' ]
# ```

# %%
import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches, text, patheffects
import cv2
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# DIREKTORI FILE DATASET DAN ANOTASINYA
ANNOTATION_DIR = "../dataset/labels/"
IMAGE_DIR = "../dataset/images/"

# %%
# MENYIMPAN INFORMASI SEMUA ANOTASINYA KE DALAM DATAFRAME
datas = {
    "nama_file": [],
    "class": [],
    "center_x": [],
    "center_y": [],
    "width": [],
    "height": []
}

for file in os.listdir(ANNOTATION_DIR):
    if file.endswith("txt"):
        file_path = "{}\{}".format(ANNOTATION_DIR, file)
        with open(file_path, "r") as f:
            for line in f.readlines():
                row = line.split()
                datas["nama_file"].append(file.split(".")[0])
                datas["class"].append(row[0])
                datas["center_x"].append(row[1])
                datas["center_y"].append(row[2])
                datas["width"].append(row[3])
                datas["height"].append(row[4])

df = pd.DataFrame(datas)
df["class"].replace({"0": "mask", "1": "no_mask"}, inplace=True)

# %%
df

# %%
jumlah_gambar = df["nama_file"].nunique()
print(f"Jumlah Gambar Dalam Dataset: {jumlah_gambar}")

# %%
label_per_gambar = df["nama_file"].value_counts().to_frame().reset_index(drop=False)
label_per_gambar.rename(columns={"index": "nama_file", "nama_file":"jumlah_label"}, inplace=True)
label_per_gambar

# %%
df.info()

# %%
# Mengubah tipe data class, center_x, center_y, width, height jadi float
df = df.astype({"center_x": float, "center_y": float, "width": float, "height": float})
df.info()

# %%
jumlah_kelas = df["class"].value_counts().to_frame().reset_index(drop=False)
jumlah_kelas.rename(columns={"index": "class", "class":"jumlah_data"}, inplace=True)
jumlah_kelas

# %%
def get_target_ds(name, df):
    """
    Fungsi ini digunakan untuk mendapatkan anotasi dari label yang
    diperoleh dari csv yang berisi informasi mengenai label dan gambar dataset
    """
    bboxes_cols = ["center_x", "center_y", "width", "height"]
    rows = df[df["nama_file"] == name[:-4]]
    return rows["class"].values, rows[bboxes_cols].values


def get_bb(bboxes, img):
    """
    Fungsi ini digunakan untuk mendapatkan lebar dan tinggi label, serta posisi dari label
    Hal ini diperlukan karena format labeling YOLO sebagai berikut:
    [x_center, y_center, width, height]
    
    x_center: posisi x-axis label yang dinormalisasi
    y_center posisi y-axis label yang dinormalisasi
    width: lebar label yang dinormalisasi
    height: tinggi label yang dinormalisasi
    """
    boxes = bboxes.copy()
    boxes[:,0] = (boxes[:,0] - boxes[:,2]*0.5)*img.shape[1]
    boxes[:,1] = (boxes[:,1] - boxes[:,3]*0.5)*img.shape[0]
    boxes[:,2] = boxes[:,2] * img.shape[1]
    boxes[:,3] = boxes[:,3] * img.shape[0]
    
    if boxes.shape[0] == 1 : return boxes
    return np.squeeze(boxes)


def img_show(img, ax = None, figsize=(7,11)):
    """ 
    Fungsi ini digunakan untuk menvisualisasikan gambar
    """
    if ax is None: fig, ax = plt.subplots(figsize=figsize)
    ax.xaxis.tick_top()
    ax.imshow(img)
    ax.axis("off")
    
    return ax


def draw_outline(obj):
    """
    Fungsi ini digunakan untuk menambahkan outline pada box / text
    """
    obj.set_path_effects([patheffects.Stroke(linewidth=4, foreground="black"), patheffects.Normal()])


def draw_box(img, ax, bb, color):
    """
    Fungsi ini digunakan untuk menggambarkan label yang akan divisualisasikan
    """
    patch = ax.add_patch(patches.Rectangle((bb[0], bb[1]), bb[2], bb[3], fill=False, edgecolor=color, lw=2))
    draw_outline(patch)

def draw_text(ax, bb, txt, disp, color):
    """
    Fungsi ini digunakan untuk menggambarkan class dari label yang akan divisualisasikan
    """
    text = ax.text(bb[0], bb[1]-disp, txt, 
                   verticalalignment="bottom", 
                   color=color, 
                   fontsize=24, 
                   )

def plot_sample(img, bboxes, labels, ax=None, figsize=(18,10)):
    """
    Fungsi ini untuk menampilkan 1 buah gambar beserta dengan labelnya
    """
    bb = get_bb(bboxes, img)
    ax = img_show(img, ax=ax)
    for i in range(len(bboxes)):
        if labels[i] == "mask":
            color = "red"
        elif labels[i] == "no_mask":
            color = "green"
        draw_box(img, ax, bb[i], color)
        draw_text(ax, bb[i], str(labels[i]), img.shape[0]*0.05, color)
        
def multiplot(dim: tuple, df, images, idxs=None, figsize=(18,10)):
    """
    Fungsi ini untuk menampilkan lebih dari satu gambar beserta dengan labelnya
    """
    if idxs is None: idxs = np.random.randint(0, len(images)-1, dim[0]*dim[1])
    fig, ax = plt.subplots(dim[0], dim[1], figsize=figsize)
    plt.subplots_adjust(wspace=0.1, hspace=0)
    fig.tight_layout()
    length = dim[0]*dim[1]
    for i in range(dim[0]):
        for j in range(dim[1]):
            length-=1
            img = images[idxs[length]]
            img_path = IMAGE_DIR + img
            labels, bboxes = get_target_ds(img, df)
            img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
            plot_sample(img, bboxes, labels, ax=ax[i][j])

# %%
images = os.listdir(IMAGE_DIR)
multiplot((3,3), df, images, figsize=(17,17))

# %%
plt.figure(figsize=(7,4))
sns.barplot(x="class", y="jumlah_data", data=jumlah_kelas)
plt.title("Jumlah Label Dataset")
plt.show()

# %%
def move_file(list_file, destination_path):
    """
    Fungsi ini digunakan untuk memindahkan file image dan anotasi menuju file yang diinginkan
    """
    if not os.path.exists(destination_path[0]):
        os.mkdir(destination_path[0])
    if not os.path.exists(destination_path[1]):
        os.mkdir(destination_path[1])
        
    for file in list_file:
        image = file+".jpg"
        txt = file+".txt"
        shutil.move(os.path.join(IMAGE_DIR, image),
                    os.path.join(destination_path[0], image))
        
        shutil.move(os.path.join(ANNOTATION_DIR, txt),
                    os.path.join(destination_path[1], txt))
        
        
# Split dataset
file_name = label_per_gambar["nama_file"]
train_image, test_image = train_test_split(file_name, test_size=0.1)

train_path = [IMAGE_DIR+"train/", ANNOTATION_DIR+"train/"]
test_path = [IMAGE_DIR+"test/", ANNOTATION_DIR+"test/"]

move_file(train_image, train_path)
move_file(test_image, test_path)

# %% [markdown]
# ### 3. Pelatihan Model
# Setelah melakukan berbagai macam preparasi, langkah selanjutnya adalah melakukan pelatihan model. Pada proyek ini, kami menggunakan YOLOv5 yang dapat diperoleh dengan menjalankan perintah pada console sebagai berikut: <br>
#
# ```
# git clone https://github.com/ultralytics/yolov5
# ```
#
# Setelah mengunduh model, langkah selanjutnya adalah melakukan instalasi depedensi yang terdapat dalam model. Kemudian langkah berikutnya adalah dengan menjalankan proses training dan diakhiri dengan proses evaluasi seperti pada source code dibawah.
#
# Pada proses ini, kami menjalankan program tersebut menggunakan google colab dan mengaktifkan GPU mode pada google collab.

# %%
# Pada proyek ini, kami menyimpan project ke dalam google drive, sehingga diperlukan syntax berikut
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Berdasarkan tempat project disimpan
# %cd '/content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/model/yolov5/'
# %pip install -qr requirements.txt
# Out:
# /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/model/yolov5
#      |████████████████████████████████| 596 kB 10.6 MB/s

# %% [markdown]
# Setelah melakukan training, hasil program disimpan ke dalam folder ```model/yolov5/runs/train/custom_model3```.
#
# File tersebut berisi:
# 1. Weight dari custom model (baik yang terakhir dan terbaik)
# 2. Hasil validasi model (baik yang diprediksi dengan yang aslinya)
# 3. Hasil training model (baik yang diprediksi dengan yang aslinya)
# 4. Grafik yang berisi loss, akurasi, confussion matrix, dll
#
# Jika kita ketahui, hasil yang diperoleh adalah sebanyak 3 folder, dimana 2 folder lainnya yakni ```custom_model``` dan ```custom_model1``` merupakan hasil pelatihan model dari epoch sebelumnya. Pembagian tersebut menurut kami adalah sebuah checkpoint dari model ketika melakukan proses training.

# %%
# !python train.py --img 640 --batch 8 --epochs 75 --data data/custom_dataset.yaml --weights yolov5s.pt --name custom_model
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/custom_dataset.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=75, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=custom_model, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2021-12-6 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt to yolov5s.pt...
# 100% 14.0M/14.0M [00:00<00:00, 52.2MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7025023 parameters, 7025023 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight, 60 weight (no decay), 60 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning
/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:00<00:00,  2.67it/s]
#                  all         22         69      0.936      0.934      0.962      0.536
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      72/74     1.89G   0.02493   0.01818 0.0008219         9       640: 100% 25/25 [00:29<00:00,  1.17s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:00<00:00,  2.69it/s]
#                  all         22         69      0.908      0.922      0.943      0.537
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      73/74     1.89G   0.02633   0.01926 0.0008923        22       640: 100% 25/25 [00:30<00:00,  1.24s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:00<00:00,  2.81it/s]
#                  all         22         69      0.922      0.922      0.958      0.533
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      74/74     1.89G   0.02565   0.01982 0.0008734        40       640: 100% 25/25 [00:30<00:00,  1.22s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:00<00:00,  2.61it/s]
#                  all         22         69      0.937      0.922       0.96      0.526
#
# 75 epochs completed in 0.697 hours.
# Optimizer stripped from runs/train/custom_model3/weights/last.pt, 14.5MB
# Optimizer stripped from runs/train/custom_model3/weights/best.pt, 14.5MB
#
# Validating runs/train/custom_model3/weights/best.pt...
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.45it/s]
#                  all         22         69      0.938      0.904      0.949      0.544
#                 mask         22         27      0.928      0.951      0.985      0.613
#              no-mask         22         42      0.947      0.857      0.914      0.475
# Results saved to runs/train/custom_model3

# %%
# Melakukan testing dengan data validasi
# !python detect.py --weights runs/train/custom_model3/weights/best.pt --img 640 --conf 0.5 --source ../../dataset/validation/
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# detect: weights=['runs/train/custom_model3/weights/best.pt'], source=../../dataset/validation/, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-124-g1075488 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/2 (1/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.029s)
# video 1/2 (2/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (3/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (4/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (5/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (6/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (7/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (8/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (9/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (10/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (11/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (12/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (13/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (14/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (15/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (16/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (17/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (18/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (19/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (20/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (21/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (22/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (23/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (24/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (25/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (26/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (27/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (28/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (29/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (30/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (31/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (32/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (33/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (34/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 5 masks, Done. (0.027s)
# video 1/2 (35/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (36/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (37/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (38/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (39/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (40/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (41/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (42/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (43/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (44/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (45/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (46/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (47/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (48/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (49/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (50/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (51/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (52/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (53/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (54/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (55/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (56/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (57/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (58/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (59/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (60/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (61/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (62/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (63/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (64/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (65/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (66/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (67/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (68/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (69/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (70/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (71/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (72/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (73/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (74/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (75/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (76/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (77/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.026s)
# video 1/2 (78/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (79/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (80/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (81/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (82/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (83/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (84/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (85/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (86/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (87/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (88/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (89/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (90/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (91/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (92/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (93/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (94/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (95/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (96/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (97/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (98/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (99/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.026s)
# video 1/2 (100/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (101/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (102/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (103/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (104/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (105/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (106/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (107/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (108/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (109/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (110/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (111/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (112/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (113/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (114/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (115/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (116/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (117/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (118/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (119/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (120/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (121/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (122/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (123/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (124/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (125/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 4 masks, Done. (0.027s)
# video 1/2 (126/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (127/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (128/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (129/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (130/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (131/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (132/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (133/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (134/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (135/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (136/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (137/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (138/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (139/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (140/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (141/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (142/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (143/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (144/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (145/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (146/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (147/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (148/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (149/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (150/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (151/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (152/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (153/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (154/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (155/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (156/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (157/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (158/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (159/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (160/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (161/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (162/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (163/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (164/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (165/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (166/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (167/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (168/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (169/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (170/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (171/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (172/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (173/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (174/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (175/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (176/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (177/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (178/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (179/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (180/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (181/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (182/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (183/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (184/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (185/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (186/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (187/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (188/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (189/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (190/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (191/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (192/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (193/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (194/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (195/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (196/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (197/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (198/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (199/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (200/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (201/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (202/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (203/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (204/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (205/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (206/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (207/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (208/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (209/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (210/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (211/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (212/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (213/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (214/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (215/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (216/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (217/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (218/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (219/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (220/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.026s)
# video 1/2 (221/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (222/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (223/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (224/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (225/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (226/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (227/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (228/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (229/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (230/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (231/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (232/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (233/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (234/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (235/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (236/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (237/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (238/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (239/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (240/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (241/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (242/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (243/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (244/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (245/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (246/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (247/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (248/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (249/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (250/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (251/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (252/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (253/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (254/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (255/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (256/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (257/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (258/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.026s)
# video 1/2 (259/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (260/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (261/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (262/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (263/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (264/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (265/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (266/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (267/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.026s)
# video 1/2 (268/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (269/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (270/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (271/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (272/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (273/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (274/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (275/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, Done. (0.027s)
# video 1/2 (276/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (277/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (278/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 2 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (279/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (280/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (281/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (282/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (283/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (284/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (285/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (286/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (287/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (288/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (289/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (290/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (291/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (292/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (293/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (294/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (295/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (296/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (297/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (298/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (299/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (300/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (301/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (302/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (303/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (304/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (305/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (306/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (307/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (308/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (309/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (310/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (311/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (312/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (313/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (314/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (315/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (316/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (317/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (318/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (319/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (320/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (321/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (322/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (323/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (324/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (325/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, 1 no-mask, Done. (0.027s)
# video 1/2 (326/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (327/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (328/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (329/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (330/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (331/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (332/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (333/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (334/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (335/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (336/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (337/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (338/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (339/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (340/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (341/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (342/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (343/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (344/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (345/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (346/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (347/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (348/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (349/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# video 1/2 (350/376) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-1.mp4: 384x640 3 masks, Done. (0.027s)
# ...
# video 2/2 (601/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (602/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (603/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 3 no-masks, Done. (0.027s)
# video 2/2 (604/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (605/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (606/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (607/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (608/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (609/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (610/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (611/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (612/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (613/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (614/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (615/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (616/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (617/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (618/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 3 no-masks, Done. (0.027s)
# video 2/2 (619/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (620/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (621/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (622/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (623/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (624/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (625/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (626/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (627/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (628/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (629/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (630/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 3 no-masks, Done. (0.027s)
# video 2/2 (631/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 3 no-masks, Done. (0.027s)
# video 2/2 (632/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (633/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (634/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (635/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (636/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (637/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 2 no-masks, Done. (0.027s)
# video 2/2 (638/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (639/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (640/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (641/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (642/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (643/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (644/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (645/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (646/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (647/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (648/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (649/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (650/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (651/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (652/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (653/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (654/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (655/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (656/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (657/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (658/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (659/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (660/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (661/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (662/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (663/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (664/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (665/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (666/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (667/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (668/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (669/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (670/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (671/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (672/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (673/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (674/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 1 no-mask, Done. (0.027s)
# video 2/2 (675/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (676/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (677/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (678/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (679/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (680/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (681/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (682/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (683/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (684/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (685/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (686/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (687/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (688/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (689/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (690/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (691/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (692/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (693/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (694/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (695/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (696/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (697/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (698/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (699/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (700/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (701/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (702/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (703/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (704/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (705/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (706/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (707/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (708/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (709/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (710/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (711/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (712/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (713/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (714/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (715/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (716/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (717/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (718/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (719/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# video 2/2 (720/720) /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/dataset/validation/video-2.mp4: 384x640 Done. (0.027s)
# Speed: 0.5ms pre-process, 26.9ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# Export Model
# !python export.py --weights runs/train/custom_model3/weights/best.pt --img 640 --include tfjs
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/custom_model3/weights/best.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=14, verbose=False, workspace=4, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tfjs']
# YOLOv5 🚀 2021-12-6 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/custom_model3/weights/best.pt (14.5 MB)
#
# TensorFlow saved_model: starting export with tensorflow 2.7.0...
#
#                  from  n    params  module                                  arguments
# 2021-12-12 03:37:28.383776: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512], [640, 640]]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(1, 640, 640, 3)]   0           []
#
#  tf_conv (TFConv)               (1, 320, 320, 32)    3488        ['input_1[0][0]']
#
#  tf_conv_1 (TFConv)             (1, 160, 160, 64)    18496       ['tf_conv[0][0]']
#
#  tfc3 (TFC3)                    (1, 160, 160, 64)    18624       ['tf_conv_1[0][0]']
#
#  tf_conv_7 (TFConv)             (1, 80, 80, 128)     73856       ['tfc3[0][0]']
#
#  tfc3_1 (TFC3)                  (1, 80, 80, 128)     115200      ['tf_conv_7[0][0]']
#
#  tf_conv_15 (TFConv)            (1, 40, 40, 256)     295168      ['tfc3_1[0][0]']
#
#  tfc3_2 (TFC3)                  (1, 40, 40, 256)     623872      ['tf_conv_15[0][0]']
#
#  tf_conv_25 (TFConv)            (1, 20, 20, 512)     1180160     ['tfc3_2[0][0]']
#
#  tfc3_3 (TFC3)                  (1, 20, 20, 512)     1181184     ['tf_conv_25[0][0]']
#
#  tfsppf (TFSPPF)                (1, 20, 20, 512)     656128      ['tfc3_3[0][0]']
#
#  tf_conv_33 (TFConv)            (1, 20, 20, 256)     131328      ['tfsppf[0][0]']
#
#  tf_upsample (TFUpsample)       (1, 40, 40, 256)     0           ['tf_conv_33[0][0]']
#
#  tf_concat (TFConcat)           (1, 40, 40, 512)     0           ['tf_upsample[0][0]',
#                                                                   'tfc3_2[0][0]']
#
#  tfc3_4 (TFC3)                  (1, 40, 40, 256)     361216      ['tf_concat[0][0]']
#
#  tf_conv_39 (TFConv)            (1, 40, 40, 128)     32896       ['tfc3_4[0][0]']
#
#  tf_upsample_1 (TFUpsample)     (1, 80, 80, 128)     0           ['tf_conv_39[0][0]']
#
#  tf_concat_1 (TFConcat)         (1, 80, 80, 256)     0           ['tf_upsample_1[0][0]',
#                                                                   'tfc3_1[0][0]']
#
#  tfc3_5 (TFC3)                  (1, 80, 80, 128)     90496       ['tf_concat_1[0][0]']
#
#  tf_conv_45 (TFConv)            (1, 40, 40, 128)     147584      ['tfc3_5[0][0]']
#
#  tf_concat_2 (TFConcat)         (1, 40, 40, 256)     0           ['tf_conv_45[0][0]',
#                                                                   'tf_conv_39[0][0]']
#
#  tfc3_6 (TFC3)                  (1, 40, 40, 256)     295680      ['tf_concat_2[0][0]']
#
#  tf_conv_51 (TFConv)            (1, 20, 20, 256)     590080      ['tfc3_6[0][0]']
#
#  tf_concat_3 (TFConcat)         (1, 20, 20, 512)     0           ['tf_conv_51[0][0]',
#                                                                   'tf_conv_33[0][0]']
#
#  tfc3_7 (TFC3)                  (1, 20, 20, 512)     1181184     ['tf_concat_3[0][0]']
#
#  tf_detect (TFDetect)           ((1, 25200, 7),      18879       ['tfc3_5[0][0]',
#                                  [(1, 3, 6400, 7),                'tfc3_6[0][0]',
#                                  (1, 3, 1600, 7),                 'tfc3_7[0][0]']
#                                  (1, 3, 400, 7)])
#
#  tf.__operators__.getitem (Slic  (1, 25200, 4)       0           ['tf_detect[0][0]']
#  ingOpLambda)
#
#  tf.split (TFOpLambda)          [(1, 25200, 1),      0           ['tf.__operators__.getitem[0][0]'
#                                  (1, 25200, 1),                  ]
#                                  (1, 25200, 1),
#                                  (1, 25200, 1)]
#
#  tf.math.truediv (TFOpLambda)   (1, 25200, 1)        0           ['tf.split[0][2]']
#
#  tf.math.truediv_1 (TFOpLambda)  (1, 25200, 1)       0           ['tf.split[0][3]']
#
#  tf.math.truediv_2 (TFOpLambda)  (1, 25200, 1)       0           ['tf.split[0][2]']
#
#  tf.math.truediv_3 (TFOpLambda)  (1, 25200, 1)       0           ['tf.split[0][3]']
#
#  tf.math.subtract (TFOpLambda)  (1, 25200, 1)        0           ['tf.split[0][0]',
#                                                                   'tf.math.truediv[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (1, 25200, 1)       0           ['tf.split[0][1]',
#  )                                                                'tf.math.truediv_1[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (1, 25200, 1)       0           ['tf.split[0][0]',
#  da)                                                              'tf.math.truediv_2[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (1, 25200, 1)       0           ['tf.split[0][1]',
#  mbda)                                                            'tf.math.truediv_3[0][0]']
#
#  tf.__operators__.getitem_2 (Sl  (1, 25200, 2)       0           ['tf_detect[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (1, 25200, 1)       0           ['tf_detect[0][0]']
#  icingOpLambda)
#
#  tf.concat (TFOpLambda)         (1, 25200, 4)        0           ['tf.math.subtract[0][0]',
#                                                                   'tf.math.subtract_1[0][0]',
#                                                                   'tf.__operators__.add[0][0]',
#                                                                   'tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (1, 25200, 2)        0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  agnostic_nms_1 (AgnosticNMS)   ((1, None, 4),       0           ['tf.concat[0][0]',
#                                  (1, None),                       'tf.__operators__.getitem_2[0][0
#                                  (1, None),                      ]',
#                                  (1,))                            'tf.math.multiply[0][0]']
#
# ==================================================================================================
# Total params: 7,015,519
# Trainable params: 0
# Non-trainable params: 7,015,519
# __________________________________________________________________________________________________
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2021-12-12 03:37:38.752499: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Found untraced functions such as tf_conv_2_layer_call_fn, tf_conv_2_layer_call_and_return_conditional_losses, tf_conv_3_layer_call_fn, tf_conv_3_layer_call_and_return_conditional_losses, tf_conv_4_layer_call_fn while saving (showing 5 of 520). These functions will not be directly callable after loading.
# Assets written to: runs/train/custom_model3/weights/best_saved_model/assets
# TensorFlow saved_model: export success, saved as runs/train/custom_model3/weights/best_saved_model (238.9 MB)
#
# TensorFlow GraphDef: starting export with tensorflow 2.7.0...
# TensorFlow GraphDef: export success, saved as runs/train/custom_model3/weights/best.pb (28.3 MB)
# requirements: tensorflowjs not found and is required by YOLOv5, attempting auto-update...
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.12.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.7.0)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.10.0.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.22.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.37.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (12.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.42.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.13.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Installing collected packages: tensorflowjs
# Successfully installed tensorflowjs-3.12.0
#
# requirements: 1 package updated per ['tensorflowjs']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow.js: starting export with tensorflowjs 3.12.0...
# Writing weight file runs/train/custom_model3/weights/best_web_model/model.json...
# TensorFlow.js: export success, saved as runs/train/custom_model3/weights/best_web_model (28.3 MB)
#
# Export complete (70.94s)
# Results saved to /content/gdrive/My Drive/Tugas-Akhir-MCDS/Project/model/yolov5/runs/train/custom_model3/weights
# Visualize with https://netron.app
